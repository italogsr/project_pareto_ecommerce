# %%
import pandas as pd

# %%
df = pd.read_json('gdg_home_test.json')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22917 entries, 0 to 22916
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ref            22006 non-null  object
#  1   url            22917 non-null  object
#  2   categoria      14777 non-null  object
#  3   nome           22917 non-null  object
#  4   imagem         22917 non-null  object
#  5   valor_riscado  19272 non-null  object
#  6   valor_boleto   19254 non-null  object
#  7   parcelas       21977 non-null  object
#  8   desconto       19209 non-null  object
# dtypes: object(9)
# memory usage: 1.6+ MB

# %%
df.head(200)
# Out:
#                                                    url           ref  \
# 0    https://www.graodegente.com.br/abajur-1/pisca-...   Ref: 116920
# 1    https://www.graodegente.com.br/abajur-1/pisca-...   Ref: 116918
# 2    https://www.graodegente.com.br/abajur-1/abajur...   Ref: 156508
# 3    https://www.graodegente.com.br/abajur-1/abajur...    Ref: 76682
# 4    https://www.graodegente.com.br/abajur-1/abajur...   Ref: 141849
# ..                                                 ...           ...
# 195  https://www.graodegente.com.br/babador-bebe/ba...   Ref: 103327
# 196  https://www.graodegente.com.br/babador-bebe/ba...   Ref: 100989
# 197  https://www.graodegente.com.br/babador-bebe/ba...    Ref: 90101
# 198  https://www.graodegente.com.br/andador/andador...   Ref: 174947
# 199  https://www.graodegente.com.br/andador/andador...   Ref: 172824
#
#                                                   nome  \
# 0      Pisca Pisca Cascata Lilás 3,4m com 200 Lâmpadas
# ...

# %%
df2 = df[['url', 'categoria']]
df2[df2['categoria'].isnull()]
# Out:
#                                                      url categoria
# 2634   https://www.graodegente.com.br/ninho-para-bebe...      None
# 2635   https://www.graodegente.com.br/moveis-quarto-c...      None
# 2636   https://www.graodegente.com.br/moveis-quarto-c...      None
# 2637   https://www.graodegente.com.br/ninho-para-bebe...      None
# 2638   https://www.graodegente.com.br/quadros-e-paine...      None
# ...                                                  ...       ...
# 22912  https://www.graodegente.com.br/carrinho-de-beb...      None
# 22913  https://www.graodegente.com.br/moveis-quarto-c...      None
# 22914  https://www.graodegente.com.br/moveis-quarto-c...      None
# 22915  https://www.graodegente.com.br/moveis-quarto-c...      None
# 22916  https://www.graodegente.com.br/moveis-quarto-c...      None
#
# [8140 rows x 2 columns]
